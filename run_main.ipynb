# %%
# !python3 "./drive/My Drive/GitHub/pytorch-cnp/main.py"
# Out:
# ----------------------------------------
#             PARAMETER TABLES
# ----------------------------------------
# batch_size :                         2
# beta1 :                            0.5
# data_type :                    float32
# dir_checkpoint : ./drive/My Drive/GitHub/pytorch-cnp/checkpoints
# dir_data :   ./drive/My Drive/datasets
# dir_log : ./drive/My Drive/GitHub/pytorch-cnp/log
# dir_result : ./drive/My Drive/GitHub/pytorch-cnp/results
# gpu_ids :                          [0]
# lr_G :                          0.0001
# mode :                           train
# name_data :                         em
# nch_in :                             1
# nch_ker :                           64
# nch_load :                           1
# nch_out :                            1
# norm :                           bnorm
# num_epoch :                        300
# num_freq_disp :                      3
# num_freq_save :                     10
# nx_in :                            512
# ...
